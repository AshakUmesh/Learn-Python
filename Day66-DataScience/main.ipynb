# %% [markdown]
# <a href="https://colab.research.google.com/github/AshakUmesh/Learn-Python/blob/main/Day66-DataScience/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# I am here to gain knowledge of different techniques for processing, managing, and visualizing data.

# %%
import pandas as pd

# %%
df=pd.read_csv('sample_employees.csv')

# %%
print(df)
# Out:
#    EmployeeID     Name Department  Age  Salary   StartDate
# 0         101    Alice         HR   29   50000  2015-06-23
# 1         102      Bob         IT   34   62000  2018-09-15
# 2         103  Charlie    Finance   41   58000  2012-11-01
# 3         104    David         IT   28   60000  2020-01-10
# 4         105      Eva  Marketing   35   55000  2019-03-12
# 5         106    Frank         HR   45   70000  2010-07-01
# 6         107    Grace    Finance   30   67000  2016-05-09
# 7         108   Hannah  Marketing   32   53000  2021-10-20
# 8         109      Ian         IT   26   61000  2022-02-17
# 9         110   Jackie         HR   38   72000  2009-04-05

# %%
df.head()
# Out:
#    EmployeeID     Name Department  Age  Salary   StartDate
# 0         101    Alice         HR   29   50000  2015-06-23
# 1         102      Bob         IT   34   62000  2018-09-15
# 2         103  Charlie    Finance   41   58000  2012-11-01
# 3         104    David         IT   28   60000  2020-01-10
# 4         105      Eva  Marketing   35   55000  2019-03-12

# %%
df.tail()
# Out:
#    EmployeeID    Name Department  Age  Salary   StartDate
# 5         106   Frank         HR   45   70000  2010-07-01
# 6         107   Grace    Finance   30   67000  2016-05-09
# 7         108  Hannah  Marketing   32   53000  2021-10-20
# 8         109     Ian         IT   26   61000  2022-02-17
# 9         110  Jackie         HR   38   72000  2009-04-05

# %%
df.Age
# Out:
# 0    29
# 1    34
# 2    41
# 3    28
# 4    35
# 5    45
# 6    30
# 7    32
# 8    26
# 9    38
# Name: Age, dtype: int64

# %%
df.Name == 'Ian'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Name, dtype: bool

# %%
df.shape
# Out:
# (10, 6)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Salary', 'StartDate'], dtype='object')

# %%
df.isna()  #check if there is NaN data
# Out:
#    EmployeeID   Name  Department    Age  Salary  StartDate
# 0       False  False       False  False   False      False
# 1       False  False       False  False   False      False
# 2       False  False       False  False   False      False
# 3       False  False       False  False   False      False
# 4       False  False       False  False   False      False
# 5       False  False       False  False   False      False
# 6       False  False       False  False   False      False
# 7       False  False       False  False   False      False
# 8       False  False       False  False   False      False
# 9       False  False       False  False   False      False

# %%
df.dropna()  #remove NaN values
# Out:
#    EmployeeID     Name Department  Age  Salary   StartDate
# 0         101    Alice         HR   29   50000  2015-06-23
# 1         102      Bob         IT   34   62000  2018-09-15
# 2         103  Charlie    Finance   41   58000  2012-11-01
# 3         104    David         IT   28   60000  2020-01-10
# 4         105      Eva  Marketing   35   55000  2019-03-12
# 5         106    Frank         HR   45   70000  2010-07-01
# 6         107    Grace    Finance   30   67000  2016-05-09
# 7         108   Hannah  Marketing   32   53000  2021-10-20
# 8         109      Ian         IT   26   61000  2022-02-17
# 9         110   Jackie         HR   38   72000  2009-04-05

# %%
df.loc[1]  #get entire row value of row-1
# Out:
# EmployeeID           102
# Name                 Bob
# Department            IT
# Age                   34
# Salary             62000
# StartDate     2018-09-15
# Name: 1, dtype: object

# %%
df.Salary.max() #return max value in that coloumn
# Out:
# 72000

# %%
df.sort_values('Salary')
# Out:
#    EmployeeID     Name Department  Age  Salary   StartDate
# 0         101    Alice         HR   29   50000  2015-06-23
# 7         108   Hannah  Marketing   32   53000  2021-10-20
# 4         105      Eva  Marketing   35   55000  2019-03-12
# 2         103  Charlie    Finance   41   58000  2012-11-01
# 3         104    David         IT   28   60000  2020-01-10
# 8         109      Ian         IT   26   61000  2022-02-17
# 1         102      Bob         IT   34   62000  2018-09-15
# 6         107    Grace    Finance   30   67000  2016-05-09
# 5         106    Frank         HR   45   70000  2010-07-01
# 9         110   Jackie         HR   38   72000  2009-04-05

# %%
df.groupby('Department').count()
# Out:
#             EmployeeID  Name  Age  Salary  StartDate
# Department
# Finance              2     2    2       2          2
# HR                   3     3    3       3          3
# IT                   3     3    3       3          3
# Marketing            2     2    2       2          2

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance      62500.0
# HR           64000.0
# IT           61000.0
# Marketing    54000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Department').Salary.mean()
# Out:
# Department
# Finance      62500.0
# HR           64000.0
# IT           61000.0
# Marketing    54000.0
# Name: Salary, dtype: float64

# %%
print(df.StartDate.dtype)
# Out:
# object

# %%
print(df.dtypes)
# Out:
# EmployeeID     int64
# Name          object
# Department    object
# Age            int64
# Salary         int64
# StartDate     object
# dtype: object

# %%
df.StartDate = pd.to_datetime(df.StartDate) #change data type from object to date

# %%
print(df.dtypes)
# Out:
# EmployeeID             int64
# Name                  object
# Department            object
# Age                    int64
# Salary                 int64
# StartDate     datetime64[ns]
# dtype: object

# %%
pivoted_df = df.pivot(index='Name',columns='Department',values='Salary')

# %%
print(pivoted_df)
# Out:
# Department  Finance       HR       IT  Marketing
# Name
# Alice           NaN  50000.0      NaN        NaN
# Bob             NaN      NaN  62000.0        NaN
# Charlie     58000.0      NaN      NaN        NaN
# David           NaN      NaN  60000.0        NaN
# Eva             NaN      NaN      NaN    55000.0
# Frank           NaN  70000.0      NaN        NaN
# Grace       67000.0      NaN      NaN        NaN
# Hannah          NaN      NaN      NaN    53000.0
# Ian             NaN      NaN  61000.0        NaN
# Jackie          NaN  72000.0      NaN        NaN

# %%
pivoted_df.fillna(0,inplace=True)
print(pivoted_df)
# Out:
# Department  Finance       HR       IT  Marketing
# Name
# Alice           0.0  50000.0      0.0        0.0
# Bob             0.0      0.0  62000.0        0.0
# Charlie     58000.0      0.0      0.0        0.0
# David           0.0      0.0  60000.0        0.0
# Eva             0.0      0.0      0.0    55000.0
# Frank           0.0  70000.0      0.0        0.0
# Grace       67000.0      0.0      0.0        0.0
# Hannah          0.0      0.0      0.0    53000.0
# Ian             0.0      0.0  61000.0        0.0
# Jackie          0.0  72000.0      0.0        0.0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.Age,df.Salary)

# %%
plt.figure(figsize=(16, 10))
plt.plot(df.Age,df.Salary)

# %%
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs Salary')
plt.plot(df.Age,df.Salary)

# %%
df['Salary'].rolling(window=2).mean().plot()
# Out:
# <Axes: >

# %%
print(df)
# Out:
#    EmployeeID     Name Department  Age  Salary  StartDate
# 0         101    Alice         HR   29   50000 2015-06-23
# 1         102      Bob         IT   34   62000 2018-09-15
# 2         103  Charlie    Finance   41   58000 2012-11-01
# 3         104    David         IT   28   60000 2020-01-10
# 4         105      Eva  Marketing   35   55000 2019-03-12
# 5         106    Frank         HR   45   70000 2010-07-01
# 6         107    Grace    Finance   30   67000 2016-05-09
# 7         108   Hannah  Marketing   32   53000 2021-10-20
# 8         109      Ian         IT   26   61000 2022-02-17
# 9         110   Jackie         HR   38   72000 2009-04-05

# %%
df[(df['Department'] == 'IT') & (df['Age'] < 50)]['Name']
# Out:
# 1      Bob
# 3    David
# 8      Ian
# Name: Name, dtype: object
